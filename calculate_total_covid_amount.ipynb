# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from calculate_total_covid_amount import total_covid_cases

# %%
total_covid_cases_route = "datasets/statewide_cases.csv"

# %%
total_covid_cases(total_covid_cases_route)
