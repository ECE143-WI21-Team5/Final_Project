# %%
import zipfile
import urllib.request
import os
import matplotlib.pyplot as plt
from datetime import timezone
from datetime import datetime
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time
import numpy as np
import itertools
import csv

from final_regression import download_data
from final_regression import convine_data_files
from final_regression import choose_dataset
from final_regression import city_regression
from final_regression import print_raw_county_data
from final_regression import prepare_county_data
from final_regression import make_predictions
from final_regression import print_predictions
from final_regression import print_test_data
from final_regression import print_residuals
from final_regression import print_difference
from final_regression import filter_counties

# %%
download_data(2014, '\\Users\\jesus\\Desktop\\143_ECE\\Final_Project\\recursive_predictions\\CO\\', 'CO')
# Out:
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2014.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2015.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2016.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2017.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2018.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2019.zip
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2020.zip

# %%
CO_data = convine_data_files(2014, '\\Users\\jesus\\Desktop\\143_ECE\\Final_Project\\recursive_predictions\\CO\\', 'CO')

# %%
county_sample = choose_dataset('CO')

# %%
county_data = filter_counties(CO_data,county_sample)
# Out:
# 20

# %%
print_raw_county_data(county_data)
# Out:
# Alameda
# Butte
# Contra Costa
# Fresno
# Humboldt
# Kern
# Los Angeles
# Marin
# Monterey
# Napa
# Orange
# Riverside
# Sacramento
# San Bernardino
# San Diego
# San Francisco
# San Mateo
# Santa Barbara
# Sonoma
# Stanislaus

# %%
test_dates, train_data_convined, test_data = prepare_county_data(county_data,county_sample, 2015,2020)
# Out:
# 313
# 53
# 26 26
# 313
# 53
# 25 25
# 313
# 53
# 26 26
# 313
# 53
# 26 26
# 313
# 53
# 20 20
# 313
# 53
# 23 23
# 313
# 53
# 21 21
# 312
# 53
# 25 25
# 312
# 53
# 21 21
# 312
# 53
# 26 26
# 313
# 53
# 21 21
# 313
# 53
# 21 21
# 313
# 53
# 26 26
# 313
# 53
# 21 21
# 313
# 53
# 26 26
# 313
# 53
# 26 26
# 313
# 53
# 26 26
# 313
# 53
# 30 30
# 311
# 51
# 26 26
# 313
# 53
# 23 23

# %%
predictions = make_predictions(train_data_convined,test_dates)
# Out:
# predictions to be made  20
# 0  counties predicted
# 1  counties predicted
# 2  counties predicted
# 3  counties predicted
# 4  counties predicted
# 5  counties predicted
# 6  counties predicted
# 7  counties predicted
# 8  counties predicted
# C:\Users\Jesus\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 9  counties predicted
# 10  counties predicted
# C:\Users\Jesus\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 11  counties predicted
# 12  counties predicted
# 13  counties predicted
# 14  counties predicted
# 15  counties predicted
# 16  counties predicted
# 17  counties predicted
# 18  counties predicted
# 19  counties predicted

# %%
print_predictions('CO', predictions, test_dates, county_sample)

# %%
print_test_data('CO', test_data,test_dates, county_sample)

# %%
print_residuals(test_data, predictions, county_sample,test_dates)

# %%
print_difference('CO',test_data,predictions,test_dates,county_sample)
# Out:
# 20 20
